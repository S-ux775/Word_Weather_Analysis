# %%
# Deliverable 1 Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy  import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-140.000, high=140.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 809

# %%
#Print last city
print(city)
# Out:
# oriximina

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dcdadb18d8f692480e0d882adc633e1a

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cockburn town
# Processing Record 2 of Set 1 | rawson
# Processing Record 3 of Set 1 | meulaboh
# Processing Record 4 of Set 1 | barra patuca
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | meru
# Processing Record 9 of Set 1 | tazovskiy
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | sept-iles
# Processing Record 12 of Set 1 | qaqortoq
# Processing Record 13 of Set 1 | leh
# Processing Record 14 of Set 1 | conde
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | matir
# City not found. Skipping...
# Processing Record 17 of Set 1 | voyvozh
# Processing Record 18 of Set 1 | polewali
# Processing Record 19 of Set 1 | vila franca do campo
# Processing Record 20 of Set 1 | grindavik
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | kruisfontein
# Processing Record 25 of Set 1 | guadalupe y calvo
# Processing Record 26 of Set 1 | bose
# Processing Record 27 of Set 1 | san carlos del zulia
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | bereda
# Processing Record 31 of Set 1 | nanortalik
# Processing Record 32 of Set 1 | medicine hat
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | dutlwe
# Processing Record 35 of Set 1 | bayonet point
# Processing Record 36 of Set 1 | kautokeino
# Processing Record 37 of Set 1 | zhigansk
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 1 | orta nova
# Processing Record 43 of Set 1 | victor harbor
# Processing Record 44 of Set 1 | cabo san lucas
# Processing Record 45 of Set 1 | marzuq
# Processing Record 46 of Set 1 | ludhiana
# Processing Record 47 of Set 1 | souillac
# Processing Record 48 of Set 1 | puerto colombia
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | dali
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | cayenne
# Processing Record 3 of Set 2 | fairhope
# Processing Record 4 of Set 2 | chifeng
# Processing Record 5 of Set 2 | los llanos de aridane
# Processing Record 6 of Set 2 | tomatlan
# Processing Record 7 of Set 2 | ormara
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | mountain home
# Processing Record 12 of Set 2 | altamont
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | baicheng
# Processing Record 17 of Set 2 | opuwo
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | espinosa
# Processing Record 21 of Set 2 | kalabo
# Processing Record 22 of Set 2 | pangnirtung
# Processing Record 23 of Set 2 | san joaquin
# Processing Record 24 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | tiznit
# Processing Record 26 of Set 2 | saldanha
# Processing Record 27 of Set 2 | puerto el triunfo
# Processing Record 28 of Set 2 | usila
# City not found. Skipping...
# Processing Record 29 of Set 2 | borogontsy
# Processing Record 30 of Set 2 | berezovyy
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | neuquen
# Processing Record 33 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 2 | dacudao
# Processing Record 35 of Set 2 | pisco
# Processing Record 36 of Set 2 | pangody
# Processing Record 37 of Set 2 | dudinka
# Processing Record 38 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 2 | la ronge
# Processing Record 40 of Set 2 | muisne
# Processing Record 41 of Set 2 | lagoa
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | pyaozerskiy
# Processing Record 44 of Set 2 | tshikapa
# Processing Record 45 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | salinopolis
# Processing Record 48 of Set 2 | marsa matruh
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 3 | karsun
# Processing Record 2 of Set 3 | mangrol
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | gogrial
# Processing Record 5 of Set 3 | digboi
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 3 | biak
# Processing Record 9 of Set 3 | san jose
# Processing Record 10 of Set 3 | mount gambier
# Processing Record 11 of Set 3 | mount darwin
# Processing Record 12 of Set 3 | kutum
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | labuhan
# Processing Record 15 of Set 3 | tezu
# Processing Record 16 of Set 3 | kalemie
# Processing Record 17 of Set 3 | tabou
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | texarkana
# Processing Record 20 of Set 3 | padampur
# Processing Record 21 of Set 3 | laguna
# Processing Record 22 of Set 3 | bara
# Processing Record 23 of Set 3 | findhorn
# Processing Record 24 of Set 3 | dubenskiy
# City not found. Skipping...
# Processing Record 25 of Set 3 | siparia
# Processing Record 26 of Set 3 | pimentel
# Processing Record 27 of Set 3 | kuusamo
# Processing Record 28 of Set 3 | merauke
# Processing Record 29 of Set 3 | havre-saint-pierre
# Processing Record 30 of Set 3 | danjiangkou
# Processing Record 31 of Set 3 | sri aman
# Processing Record 32 of Set 3 | huancabamba
# Processing Record 33 of Set 3 | vestmannaeyjar
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | caravelas
# Processing Record 36 of Set 3 | challans
# Processing Record 37 of Set 3 | shahrud
# Processing Record 38 of Set 3 | duz
# City not found. Skipping...
# Processing Record 39 of Set 3 | linguere
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | yanam
# Processing Record 42 of Set 3 | upernavik
# Processing Record 43 of Set 3 | cuamba
# Processing Record 44 of Set 3 | pokhara
# Processing Record 45 of Set 3 | cambridge
# Processing Record 46 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 3 | keshan
# City not found. Skipping...
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 3 | bukachacha
# Processing Record 50 of Set 3 | tonantins
# Processing Record 1 of Set 4 | flinders
# Processing Record 2 of Set 4 | ancud
# Processing Record 3 of Set 4 | torbay
# Processing Record 4 of Set 4 | koslan
# Processing Record 5 of Set 4 | hay river
# Processing Record 6 of Set 4 | fortuna
# Processing Record 7 of Set 4 | key west
# Processing Record 8 of Set 4 | konibodom
# Processing Record 9 of Set 4 | san quintin
# Processing Record 10 of Set 4 | petrolia
# Processing Record 11 of Set 4 | miri
# Processing Record 12 of Set 4 | beyneu
# Processing Record 13 of Set 4 | estevan
# Processing Record 14 of Set 4 | saint-philippe
# Processing Record 15 of Set 4 | saint-augustin
# Processing Record 16 of Set 4 | ribeira grande
# Processing Record 17 of Set 4 | strezhevoy
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | krasnoselkup
# Processing Record 20 of Set 4 | lazaro cardenas
# Processing Record 21 of Set 4 | chapais
# Processing Record 22 of Set 4 | ponta do sol
# Processing Record 23 of Set 4 | diffa
# Processing Record 24 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 25 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 4 | shkotovo-26
# City not found. Skipping...
# Processing Record 27 of Set 4 | puerto ayora
# Processing Record 28 of Set 4 | belaya kholunitsa
# Processing Record 29 of Set 4 | alta floresta
# Processing Record 30 of Set 4 | newport
# Processing Record 31 of Set 4 | emirdag
# Processing Record 32 of Set 4 | jidong
# Processing Record 33 of Set 4 | nha trang
# Processing Record 34 of Set 4 | cabedelo
# Processing Record 35 of Set 4 | elizabeth city
# Processing Record 36 of Set 4 | cardston
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | saurimo
# Processing Record 39 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 4 | kamenka
# Processing Record 41 of Set 4 | nenjiang
# Processing Record 42 of Set 4 | atambua
# Processing Record 43 of Set 4 | vaxjo
# Processing Record 44 of Set 4 | fort nelson
# Processing Record 45 of Set 4 | bambanglipuro
# Processing Record 46 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 4 | yumen
# Processing Record 48 of Set 4 | geraldton
# Processing Record 49 of Set 4 | naberera
# Processing Record 50 of Set 4 | benguela
# Processing Record 1 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 5 | husavik
# Processing Record 3 of Set 5 | cidreira
# Processing Record 4 of Set 5 | gerash
# Processing Record 5 of Set 5 | carnarvon
# Processing Record 6 of Set 5 | kuching
# Processing Record 7 of Set 5 | mutis
# Processing Record 8 of Set 5 | zhuanghe
# Processing Record 9 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 5 | aswan
# Processing Record 11 of Set 5 | karratha
# Processing Record 12 of Set 5 | uzumlu
# City not found. Skipping...
# Processing Record 13 of Set 5 | usinsk
# Processing Record 14 of Set 5 | chuy
# Processing Record 15 of Set 5 | clifton
# Processing Record 16 of Set 5 | faya
# Processing Record 17 of Set 5 | excelsior springs
# Processing Record 18 of Set 5 | pombas
# Processing Record 19 of Set 5 | aquiraz
# Processing Record 20 of Set 5 | sistranda
# Processing Record 21 of Set 5 | tocopilla
# Processing Record 22 of Set 5 | hoquiam
# Processing Record 23 of Set 5 | nichinan
# Processing Record 24 of Set 5 | houma
# Processing Record 25 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 26 of Set 5 | saint george
# Processing Record 27 of Set 5 | pangoa
# Processing Record 28 of Set 5 | srandakan
# Processing Record 29 of Set 5 | ruteng
# Processing Record 30 of Set 5 | poplar bluff
# Processing Record 31 of Set 5 | mahon
# Processing Record 32 of Set 5 | mbala
# Processing Record 33 of Set 5 | clarksdale
# Processing Record 34 of Set 5 | xinmin
# Processing Record 35 of Set 5 | kytlym
# City not found. Skipping...
# Processing Record 36 of Set 5 | atar
# Processing Record 37 of Set 5 | limoges
# Processing Record 38 of Set 5 | marrakesh
# Processing Record 39 of Set 5 | port lincoln
# Processing Record 40 of Set 5 | palmerston
# Processing Record 41 of Set 5 | batagay-alyta
# Processing Record 42 of Set 5 | clyde river
# Processing Record 43 of Set 5 | juneau
# Processing Record 44 of Set 5 | iqaluit
# Processing Record 45 of Set 5 | bolshaya rechka
# Processing Record 46 of Set 5 | grande prairie
# Processing Record 47 of Set 5 | praia da vitoria
# Processing Record 48 of Set 5 | honghu
# Processing Record 49 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 50 of Set 5 | salalah
# Processing Record 1 of Set 6 | akdepe
# Processing Record 2 of Set 6 | diapaga
# Processing Record 3 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 6 | kalmunai
# Processing Record 5 of Set 6 | santa catarina de tepehuanes
# Processing Record 6 of Set 6 | high rock
# Processing Record 7 of Set 6 | davila
# Processing Record 8 of Set 6 | kanina
# Processing Record 9 of Set 6 | manubah
# City not found. Skipping...
# Processing Record 10 of Set 6 | ixtapa
# Processing Record 11 of Set 6 | tasiilaq
# Processing Record 12 of Set 6 | alihe
# Processing Record 13 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 14 of Set 6 | tanete
# Processing Record 15 of Set 6 | port hardy
# Processing Record 16 of Set 6 | lasa
# Processing Record 17 of Set 6 | sao filipe
# Processing Record 18 of Set 6 | znamenskoye
# Processing Record 19 of Set 6 | damietta
# Processing Record 20 of Set 6 | jining
# Processing Record 21 of Set 6 | balti
# Processing Record 22 of Set 6 | teguldet
# Processing Record 23 of Set 6 | ranong
# Processing Record 24 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 25 of Set 6 | petushki
# Processing Record 26 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 6 | turukhansk
# Processing Record 28 of Set 6 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | sandwick
# Processing Record 30 of Set 6 | inhambane
# Processing Record 31 of Set 6 | butembo
# Processing Record 32 of Set 6 | portland
# Processing Record 33 of Set 6 | rubio
# Processing Record 34 of Set 6 | erenhot
# Processing Record 35 of Set 6 | constitucion
# Processing Record 36 of Set 6 | onega
# Processing Record 37 of Set 6 | tura
# Processing Record 38 of Set 6 | lompoc
# Processing Record 39 of Set 6 | tynaarlo
# Processing Record 40 of Set 6 | contamana
# Processing Record 41 of Set 6 | goya
# Processing Record 42 of Set 6 | tessalit
# Processing Record 43 of Set 6 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 44 of Set 6 | martapura
# Processing Record 45 of Set 6 | ucluelet
# Processing Record 46 of Set 6 | dvinskoy
# Processing Record 47 of Set 6 | mogadishu
# Processing Record 48 of Set 6 | prince george
# Processing Record 49 of Set 6 | saint augustine
# Processing Record 50 of Set 6 | bengkulu
# Processing Record 1 of Set 7 | chicama
# Processing Record 2 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 7 | sibu
# Processing Record 4 of Set 7 | teya
# Processing Record 5 of Set 7 | narsaq
# Processing Record 6 of Set 7 | kolyshley
# Processing Record 7 of Set 7 | santa cruz
# Processing Record 8 of Set 7 | baykit
# Processing Record 9 of Set 7 | coihaique
# Processing Record 10 of Set 7 | algiers
# Processing Record 11 of Set 7 | puerto palomas
# Processing Record 12 of Set 7 | mbandaka
# Processing Record 13 of Set 7 | verdalsora
# City not found. Skipping...
# Processing Record 14 of Set 7 | rio grande
# Processing Record 15 of Set 7 | moche
# Processing Record 16 of Set 7 | hambantota
# Processing Record 17 of Set 7 | andra
# Processing Record 18 of Set 7 | rocha
# Processing Record 19 of Set 7 | khandbari
# Processing Record 20 of Set 7 | quelimane
# Processing Record 21 of Set 7 | manono
# Processing Record 22 of Set 7 | san vicente
# Processing Record 23 of Set 7 | baruun-urt
# Processing Record 24 of Set 7 | semirom
# Processing Record 25 of Set 7 | boende
# Processing Record 26 of Set 7 | hirara
# Processing Record 27 of Set 7 | awjilah
# Processing Record 28 of Set 7 | madimba
# Processing Record 29 of Set 7 | broome
# Processing Record 30 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 7 | japura
# Processing Record 32 of Set 7 | safford
# Processing Record 33 of Set 7 | berdigestyakh
# Processing Record 34 of Set 7 | barkly west
# Processing Record 35 of Set 7 | requena
# Processing Record 36 of Set 7 | hoopstad
# Processing Record 37 of Set 7 | santa barbara
# Processing Record 38 of Set 7 | gap
# Processing Record 39 of Set 7 | salinas
# Processing Record 40 of Set 7 | bilma
# Processing Record 41 of Set 7 | ilulissat
# Processing Record 42 of Set 7 | tommot
# Processing Record 43 of Set 7 | scarborough
# Processing Record 44 of Set 7 | umm lajj
# Processing Record 45 of Set 7 | port augusta
# Processing Record 46 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 47 of Set 7 | parry sound
# Processing Record 48 of Set 7 | soloneshnoye
# Processing Record 49 of Set 7 | rio gallegos
# Processing Record 50 of Set 7 | kapit
# Processing Record 1 of Set 8 | berlevag
# Processing Record 2 of Set 8 | solsvik
# City not found. Skipping...
# Processing Record 3 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 8 | viedma
# Processing Record 5 of Set 8 | the pas
# Processing Record 6 of Set 8 | kuryk
# Processing Record 7 of Set 8 | airai
# Processing Record 8 of Set 8 | muli
# Processing Record 9 of Set 8 | sokoto
# Processing Record 10 of Set 8 | hobart
# Processing Record 11 of Set 8 | port hawkesbury
# Processing Record 12 of Set 8 | teknaf
# Processing Record 13 of Set 8 | glubokoe
# City not found. Skipping...
# Processing Record 14 of Set 8 | olafsvik
# Processing Record 15 of Set 8 | monastyrshchina
# Processing Record 16 of Set 8 | urozhaynoye
# Processing Record 17 of Set 8 | balc
# Processing Record 18 of Set 8 | klaksvik
# Processing Record 19 of Set 8 | qingdao
# Processing Record 20 of Set 8 | ust-maya
# Processing Record 21 of Set 8 | mangai
# Processing Record 22 of Set 8 | taoudenni
# Processing Record 23 of Set 8 | victoria
# Processing Record 24 of Set 8 | acajutla
# Processing Record 25 of Set 8 | el wasta
# City not found. Skipping...
# Processing Record 26 of Set 8 | kopyevo
# City not found. Skipping...
# Processing Record 27 of Set 8 | iwanai
# Processing Record 28 of Set 8 | shalyhyne
# Processing Record 29 of Set 8 | ginir
# Processing Record 30 of Set 8 | manta
# Processing Record 31 of Set 8 | hami
# Processing Record 32 of Set 8 | la roda
# Processing Record 33 of Set 8 | talnakh
# Processing Record 34 of Set 8 | port blair
# Processing Record 35 of Set 8 | camocim
# Processing Record 36 of Set 8 | guerrero negro
# Processing Record 37 of Set 8 | makat
# Processing Record 38 of Set 8 | fort walton beach
# Processing Record 39 of Set 8 | aklavik
# Processing Record 40 of Set 8 | buraydah
# Processing Record 41 of Set 8 | san francisco de macoris
# Processing Record 42 of Set 8 | aksarka
# Processing Record 43 of Set 8 | balkhash
# Processing Record 44 of Set 8 | belmonte
# Processing Record 45 of Set 8 | simao
# Processing Record 46 of Set 8 | muros
# Processing Record 47 of Set 8 | moose factory
# Processing Record 48 of Set 8 | baculin
# Processing Record 49 of Set 8 | birao
# Processing Record 50 of Set 8 | teguise
# Processing Record 1 of Set 9 | mogzon
# Processing Record 2 of Set 9 | burkburnett
# Processing Record 3 of Set 9 | bastia
# Processing Record 4 of Set 9 | aykhal
# Processing Record 5 of Set 9 | bunia
# Processing Record 6 of Set 9 | santiago
# Processing Record 7 of Set 9 | curico
# Processing Record 8 of Set 9 | el cope
# Processing Record 9 of Set 9 | chany
# Processing Record 10 of Set 9 | port-gentil
# Processing Record 11 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 12 of Set 9 | dingle
# Processing Record 13 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 14 of Set 9 | takhatgarh
# Processing Record 15 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 9 | pleasant grove
# Processing Record 17 of Set 9 | dauriya
# Processing Record 18 of Set 9 | henties bay
# Processing Record 19 of Set 9 | evansville
# Processing Record 20 of Set 9 | khandyga
# Processing Record 21 of Set 9 | sorong
# Processing Record 22 of Set 9 | cuenca
# Processing Record 23 of Set 9 | hailey
# Processing Record 24 of Set 9 | akyab
# Processing Record 25 of Set 9 | imeni poliny osipenko
# Processing Record 26 of Set 9 | kosa
# Processing Record 27 of Set 9 | richards bay
# Processing Record 28 of Set 9 | sagua la grande
# Processing Record 29 of Set 9 | port hedland
# Processing Record 30 of Set 9 | porto velho
# Processing Record 31 of Set 9 | luderitz
# Processing Record 32 of Set 9 | puerto rondon
# Processing Record 33 of Set 9 | uarini
# Processing Record 34 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 9 | rehoboth
# Processing Record 36 of Set 9 | saint-joseph
# Processing Record 37 of Set 9 | yar-sale
# Processing Record 38 of Set 9 | bocaranga
# City not found. Skipping...
# Processing Record 39 of Set 9 | kaliua
# Processing Record 40 of Set 9 | sishui
# Processing Record 41 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 9 | gambela
# Processing Record 43 of Set 9 | hilo
# Processing Record 44 of Set 9 | denpasar
# Processing Record 45 of Set 9 | ponta delgada
# Processing Record 46 of Set 9 | sosnovo-ozerskoye
# Processing Record 47 of Set 9 | coro
# Processing Record 48 of Set 9 | senador jose porfirio
# Processing Record 49 of Set 9 | lekoni
# Processing Record 50 of Set 9 | harer
# Processing Record 1 of Set 10 | ambilobe
# Processing Record 2 of Set 10 | dolores
# Processing Record 3 of Set 10 | lhokseumawe
# Processing Record 4 of Set 10 | churhat
# Processing Record 5 of Set 10 | sigerfjord
# City not found. Skipping...
# Processing Record 6 of Set 10 | tornio
# Processing Record 7 of Set 10 | sakakah
# Processing Record 8 of Set 10 | lingyuan
# Processing Record 9 of Set 10 | eden
# Processing Record 10 of Set 10 | umba
# Processing Record 11 of Set 10 | shimoda
# Processing Record 12 of Set 10 | pereyaslovskaya
# Processing Record 13 of Set 10 | oristano
# Processing Record 14 of Set 10 | bodden town
# Processing Record 15 of Set 10 | chikwawa
# Processing Record 16 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 10 | aksehir
# Processing Record 18 of Set 10 | kudymkar
# Processing Record 19 of Set 10 | paris
# Processing Record 20 of Set 10 | paungde
# Processing Record 21 of Set 10 | alyangula
# Processing Record 22 of Set 10 | polyarnyy
# Processing Record 23 of Set 10 | katobu
# Processing Record 24 of Set 10 | kysyl-syr
# Processing Record 25 of Set 10 | bredy
# Processing Record 26 of Set 10 | seydi
# Processing Record 27 of Set 10 | kropotkin
# Processing Record 28 of Set 10 | vidim
# Processing Record 29 of Set 10 | ginda
# Processing Record 30 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 31 of Set 10 | barcelona
# Processing Record 32 of Set 10 | marsaxlokk
# Processing Record 33 of Set 10 | guatire
# Processing Record 34 of Set 10 | guiratinga
# Processing Record 35 of Set 10 | tumaco
# Processing Record 36 of Set 10 | bud
# Processing Record 37 of Set 10 | sao joao do piaui
# Processing Record 38 of Set 10 | sumbuya
# Processing Record 39 of Set 10 | timra
# Processing Record 40 of Set 10 | bima
# Processing Record 41 of Set 10 | capoterra
# Processing Record 42 of Set 10 | raudeberg
# Processing Record 43 of Set 10 | huarmey
# Processing Record 44 of Set 10 | suleja
# Processing Record 45 of Set 10 | mutare
# Processing Record 46 of Set 10 | araouane
# Processing Record 47 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 10 | nianzishan
# Processing Record 49 of Set 10 | proti
# Processing Record 50 of Set 10 | longyearbyen
# Processing Record 1 of Set 11 | hualmay
# Processing Record 2 of Set 11 | wanning
# Processing Record 3 of Set 11 | eyl
# Processing Record 4 of Set 11 | freeport
# Processing Record 5 of Set 11 | vondrozo
# Processing Record 6 of Set 11 | port alberni
# Processing Record 7 of Set 11 | luwuk
# Processing Record 8 of Set 11 | sayyan
# Processing Record 9 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 10 of Set 11 | saint-francois
# Processing Record 11 of Set 11 | batagay
# Processing Record 12 of Set 11 | maidstone
# Processing Record 13 of Set 11 | hinton
# Processing Record 14 of Set 11 | coruripe
# Processing Record 15 of Set 11 | torfyanoy
# Processing Record 16 of Set 11 | warrington
# Processing Record 17 of Set 11 | hope
# Processing Record 18 of Set 11 | nago
# Processing Record 19 of Set 11 | mecca
# Processing Record 20 of Set 11 | gat
# Processing Record 21 of Set 11 | garowe
# Processing Record 22 of Set 11 | la mata
# Processing Record 23 of Set 11 | san patricio
# Processing Record 24 of Set 11 | mount isa
# Processing Record 25 of Set 11 | kirundo
# Processing Record 26 of Set 11 | longhua
# Processing Record 27 of Set 11 | votkinsk
# Processing Record 28 of Set 11 | woodway
# Processing Record 29 of Set 11 | hamilton
# Processing Record 30 of Set 11 | tukrah
# Processing Record 31 of Set 11 | toulepleu
# City not found. Skipping...
# Processing Record 32 of Set 11 | san martin
# Processing Record 33 of Set 11 | bria
# Processing Record 34 of Set 11 | kloulklubed
# Processing Record 35 of Set 11 | swan river
# Processing Record 36 of Set 11 | iquique
# Processing Record 37 of Set 11 | vardo
# Processing Record 38 of Set 11 | laval
# Processing Record 39 of Set 11 | zaysan
# Processing Record 40 of Set 11 | hobyo
# Processing Record 41 of Set 11 | kidal
# Processing Record 42 of Set 11 | windsor
# Processing Record 43 of Set 11 | oistins
# Processing Record 44 of Set 11 | maraba
# Processing Record 45 of Set 11 | prince albert
# Processing Record 46 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 11 | knysna
# Processing Record 48 of Set 11 | rosita
# Processing Record 49 of Set 11 | ketchikan
# Processing Record 50 of Set 11 | comodoro rivadavia
# Processing Record 1 of Set 12 | sainte-rose
# Processing Record 2 of Set 12 | lakselv
# Processing Record 3 of Set 12 | antigonish
# Processing Record 4 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 5 of Set 12 | alice springs
# Processing Record 6 of Set 12 | finnsnes
# Processing Record 7 of Set 12 | aragats
# Processing Record 8 of Set 12 | mashivka
# Processing Record 9 of Set 12 | lamu
# Processing Record 10 of Set 12 | jian
# Processing Record 11 of Set 12 | marsh harbour
# Processing Record 12 of Set 12 | kodinsk
# Processing Record 13 of Set 12 | mana
# Processing Record 14 of Set 12 | nagato
# Processing Record 15 of Set 12 | calamar
# Processing Record 16 of Set 12 | iracoubo
# Processing Record 17 of Set 12 | saint-leu
# Processing Record 18 of Set 12 | nyrob
# Processing Record 19 of Set 12 | sivas
# Processing Record 20 of Set 12 | mandalgovi
# Processing Record 21 of Set 12 | isla mujeres
# Processing Record 22 of Set 12 | sur
# Processing Record 23 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 12 | kungurtug
# Processing Record 25 of Set 12 | pedasi
# Processing Record 26 of Set 12 | svetlaya
# Processing Record 27 of Set 12 | aasiaat
# Processing Record 28 of Set 12 | necochea
# Processing Record 29 of Set 12 | soyo
# Processing Record 30 of Set 12 | bandarbeyla
# Processing Record 31 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 32 of Set 12 | jiujiang
# Processing Record 33 of Set 12 | tanda
# Processing Record 34 of Set 12 | stratford
# Processing Record 35 of Set 12 | canico
# Processing Record 36 of Set 12 | kanniyakumari
# Processing Record 37 of Set 12 | ternate
# Processing Record 38 of Set 12 | silvassa
# Processing Record 39 of Set 12 | abastumani
# Processing Record 40 of Set 12 | deputatskiy
# Processing Record 41 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 12 | rio de janeiro
# Processing Record 43 of Set 12 | xichang
# Processing Record 44 of Set 12 | catuday
# Processing Record 45 of Set 12 | asosa
# Processing Record 46 of Set 12 | malia
# Processing Record 47 of Set 12 | diego de almagro
# Processing Record 48 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 49 of Set 12 | tsaratanana
# Processing Record 50 of Set 12 | basco
# Processing Record 1 of Set 13 | prieska
# Processing Record 2 of Set 13 | pontiac
# Processing Record 3 of Set 13 | saint-pierre
# Processing Record 4 of Set 13 | gillette
# Processing Record 5 of Set 13 | balykshi
# Processing Record 6 of Set 13 | anzio
# Processing Record 7 of Set 13 | abu kamal
# Processing Record 8 of Set 13 | igurubi
# Processing Record 9 of Set 13 | salima
# Processing Record 10 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 13 | kalaleh
# Processing Record 12 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 14 of Set 13 | novo aripuana
# Processing Record 15 of Set 13 | kota kinabalu
# Processing Record 16 of Set 13 | kiruna
# Processing Record 17 of Set 13 | kununurra
# Processing Record 18 of Set 13 | moa
# Processing Record 19 of Set 13 | codrington
# Processing Record 20 of Set 13 | nzega
# Processing Record 21 of Set 13 | sindou
# Processing Record 22 of Set 13 | fargo
# Processing Record 23 of Set 13 | karlstad
# Processing Record 24 of Set 13 | ostrovnoy
# Processing Record 25 of Set 13 | lintgen
# Processing Record 26 of Set 13 | novyy urengoy
# Processing Record 27 of Set 13 | nhamunda
# Processing Record 28 of Set 13 | rio branco
# Processing Record 29 of Set 13 | syamzha
# Processing Record 30 of Set 13 | mocorito
# Processing Record 31 of Set 13 | taltal
# Processing Record 32 of Set 13 | tamiahua
# Processing Record 33 of Set 13 | general roca
# Processing Record 34 of Set 13 | san carlos
# Processing Record 35 of Set 13 | tongren
# Processing Record 36 of Set 13 | sitka
# Processing Record 37 of Set 13 | littlehampton
# Processing Record 38 of Set 13 | bubaque
# Processing Record 39 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 40 of Set 13 | korla
# Processing Record 41 of Set 13 | mayahi
# Processing Record 42 of Set 13 | wageningen
# Processing Record 43 of Set 13 | sao geraldo do araguaia
# Processing Record 44 of Set 13 | santa marta
# Processing Record 45 of Set 13 | gibara
# Processing Record 46 of Set 13 | mayo
# Processing Record 47 of Set 13 | dauphin
# Processing Record 48 of Set 13 | pilani
# Processing Record 49 of Set 13 | ivoti
# Processing Record 50 of Set 13 | marechal candido rondon
# Processing Record 1 of Set 14 | carutapera
# Processing Record 2 of Set 14 | vojens
# Processing Record 3 of Set 14 | san francisco del mar
# Processing Record 4 of Set 14 | lashio
# Processing Record 5 of Set 14 | totness
# Processing Record 6 of Set 14 | kargasok
# Processing Record 7 of Set 14 | sungai besar
# Processing Record 8 of Set 14 | krasnokamensk
# Processing Record 9 of Set 14 | glenwood springs
# Processing Record 10 of Set 14 | akhnur
# Processing Record 11 of Set 14 | oeiras
# Processing Record 12 of Set 14 | kinkala
# Processing Record 13 of Set 14 | tignere
# Processing Record 14 of Set 14 | saquena
# Processing Record 15 of Set 14 | harindanga
# Processing Record 16 of Set 14 | amparai
# City not found. Skipping...
# Processing Record 17 of Set 14 | ust-kuyga
# Processing Record 18 of Set 14 | aioi
# Processing Record 19 of Set 14 | asfi
# Processing Record 20 of Set 14 | buenos aires
# Processing Record 21 of Set 14 | myitkyina
# Processing Record 22 of Set 14 | verkhoyansk
# Processing Record 23 of Set 14 | goderich
# Processing Record 24 of Set 14 | bar harbor
# Processing Record 25 of Set 14 | bac lieu
# Processing Record 26 of Set 14 | shieli
# Processing Record 27 of Set 14 | tahoua
# Processing Record 28 of Set 14 | ferme-neuve
# Processing Record 29 of Set 14 | thiruvananthapuram
# Processing Record 30 of Set 14 | gravdal
# Processing Record 31 of Set 14 | cheney
# Processing Record 32 of Set 14 | anshun
# Processing Record 33 of Set 14 | liverpool
# Processing Record 34 of Set 14 | oktyabrskiy
# Processing Record 35 of Set 14 | muhos
# Processing Record 36 of Set 14 | mehamn
# Processing Record 37 of Set 14 | andros town
# Processing Record 38 of Set 14 | jega
# Processing Record 39 of Set 14 | jacqueville
# Processing Record 40 of Set 14 | ouadda
# Processing Record 41 of Set 14 | kearney
# Processing Record 42 of Set 14 | vieux-habitants
# Processing Record 43 of Set 14 | kholm-zhirkovskiy
# Processing Record 44 of Set 14 | carballo
# Processing Record 45 of Set 14 | winneba
# Processing Record 46 of Set 14 | tarakan
# Processing Record 47 of Set 14 | gazanjyk
# Processing Record 48 of Set 14 | adjumani
# Processing Record 49 of Set 14 | devils lake
# Processing Record 50 of Set 14 | sao luis
# Processing Record 1 of Set 15 | sao felix do xingu
# Processing Record 2 of Set 15 | gamboula
# Processing Record 3 of Set 15 | andenes
# Processing Record 4 of Set 15 | bezhanitsy
# Processing Record 5 of Set 15 | coquimbo
# Processing Record 6 of Set 15 | mopti
# Processing Record 7 of Set 15 | daxian
# City not found. Skipping...
# Processing Record 8 of Set 15 | bonthe
# Processing Record 9 of Set 15 | poltavka
# Processing Record 10 of Set 15 | gornopravdinsk
# Processing Record 11 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 12 of Set 15 | wawa
# Processing Record 13 of Set 15 | lagos
# Processing Record 14 of Set 15 | andrelandia
# Processing Record 15 of Set 15 | aranos
# Processing Record 16 of Set 15 | penzance
# Processing Record 17 of Set 15 | labuan
# Processing Record 18 of Set 15 | afyonkarahisar
# Processing Record 19 of Set 15 | nabire
# Processing Record 20 of Set 15 | santo amaro da imperatriz
# Processing Record 21 of Set 15 | coahuayana
# Processing Record 22 of Set 15 | phan thiet
# Processing Record 23 of Set 15 | swellendam
# Processing Record 24 of Set 15 | pozo colorado
# Processing Record 25 of Set 15 | general pico
# Processing Record 26 of Set 15 | syracuse
# Processing Record 27 of Set 15 | kavaratti
# Processing Record 28 of Set 15 | nadym
# Processing Record 29 of Set 15 | garmsar
# Processing Record 30 of Set 15 | trinidad
# Processing Record 31 of Set 15 | ulundurpettai
# City not found. Skipping...
# Processing Record 32 of Set 15 | karaj
# Processing Record 33 of Set 15 | sulangan
# Processing Record 34 of Set 15 | progreso
# Processing Record 35 of Set 15 | kamir
# Processing Record 36 of Set 15 | surt
# Processing Record 37 of Set 15 | banda aceh
# Processing Record 38 of Set 15 | fallon
# Processing Record 39 of Set 15 | zaraza
# Processing Record 40 of Set 15 | diamantino
# Processing Record 41 of Set 15 | nandgaon
# Processing Record 42 of Set 15 | namibe
# Processing Record 43 of Set 15 | karpogory
# Processing Record 44 of Set 15 | serenje
# Processing Record 45 of Set 15 | dicabisagan
# Processing Record 46 of Set 15 | angoche
# Processing Record 47 of Set 15 | derbent
# Processing Record 48 of Set 15 | miraflores
# Processing Record 49 of Set 15 | portpatrick
# City not found. Skipping...
# Processing Record 50 of Set 15 | matara
# Processing Record 1 of Set 16 | manadhoo
# Processing Record 2 of Set 16 | nhulunbuy
# Processing Record 3 of Set 16 | cabiraoan
# Processing Record 4 of Set 16 | balabac
# Processing Record 5 of Set 16 | aksu
# Processing Record 6 of Set 16 | matagami
# Processing Record 7 of Set 16 | touba
# Processing Record 8 of Set 16 | sijunjung
# Processing Record 9 of Set 16 | churapcha
# Processing Record 10 of Set 16 | dabakala
# Processing Record 11 of Set 16 | obzor
# Processing Record 12 of Set 16 | san juan tepa
# Processing Record 13 of Set 16 | tananger
# Processing Record 14 of Set 16 | mantua
# Processing Record 15 of Set 16 | ilhabela
# Processing Record 16 of Set 16 | sao joao da barra
# Processing Record 17 of Set 16 | yulara
# Processing Record 18 of Set 16 | chake chake
# Processing Record 19 of Set 16 | naryan-mar
# Processing Record 20 of Set 16 | thinadhoo
# Processing Record 21 of Set 16 | brunico
# Processing Record 22 of Set 16 | sulphur springs
# Processing Record 23 of Set 16 | canyon
# Processing Record 24 of Set 16 | jetalsar
# Processing Record 25 of Set 16 | manuk mangkaw
# Processing Record 26 of Set 16 | san luis
# Processing Record 27 of Set 16 | quatre cocos
# Processing Record 28 of Set 16 | oyama
# Processing Record 29 of Set 16 | kaveripattinam
# Processing Record 30 of Set 16 | touros
# Processing Record 31 of Set 16 | jacareacanga
# Processing Record 32 of Set 16 | manokwari
# Processing Record 33 of Set 16 | cururupu
# Processing Record 34 of Set 16 | shelomi
# Processing Record 35 of Set 16 | nuuk
# Processing Record 36 of Set 16 | zhob
# Processing Record 37 of Set 16 | ajdabiya
# Processing Record 38 of Set 16 | yurga
# Processing Record 39 of Set 16 | ust-tsilma
# Processing Record 40 of Set 16 | fukue
# Processing Record 41 of Set 16 | sredneuralsk
# Processing Record 42 of Set 16 | thilogne
# City not found. Skipping...
# Processing Record 43 of Set 16 | del rio
# Processing Record 44 of Set 16 | chapleau
# Processing Record 45 of Set 16 | sao borja
# Processing Record 46 of Set 16 | den helder
# Processing Record 47 of Set 16 | lincoln
# Processing Record 48 of Set 16 | lipin bor
# Processing Record 49 of Set 16 | saint andrews
# Processing Record 50 of Set 16 | sabha
# Processing Record 1 of Set 17 | manggar
# Processing Record 2 of Set 17 | acarau
# Processing Record 3 of Set 17 | chulman
# Processing Record 4 of Set 17 | matadi
# Processing Record 5 of Set 17 | vila velha
# Processing Record 6 of Set 17 | glogow
# Processing Record 7 of Set 17 | agadez
# Processing Record 8 of Set 17 | yueyang
# Processing Record 9 of Set 17 | oriximina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Cockburn Town      TC  21.4612  -71.1419     83.43        74           5
# 1          Rawson      AR -43.3002  -65.1023     44.40        61          98
# 2        Meulaboh      ID   4.1363   96.1285     74.21        87          99
# 3    Barra Patuca      HN  15.8000  -84.2833     81.21        80          73
# 4       Busselton      AU -33.6500  115.3333     50.94        78          89
# 5       Esperance      AU -33.8667  121.9000     55.42        69          60
# 6  Port Elizabeth      ZA -33.9180   25.5701     55.69        98           0
# 7            Meru      KE   0.0463   37.6559     58.57        80          78
# 8       Tazovskiy      RU  67.4667   78.7000     30.49        82          18
# 9          Dikson      RU  73.5069   80.5464     37.63        87         100
#
#    Wind Speed Current Description
# 0       11.14           clear sky
# 1       14.23     overcast clouds
# 2        4.41     overcast clouds
# 3        7.61       broken clouds
# 4        6.69     overcast clouds
# 5       13.11       broken clouds
# 6        2.30           clear sky
# 7        5.55       broken clouds
# 8        9.91          few clouds
# 9       20.47     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
